# %% [markdown]
# ## Problématique sur les couples
# A partir de l'enquete de Stanford ["How Couples Meet and Stay Together (HCMST)"](https://data.stanford.edu/hcmst), dont l'abréviation est HCMST.
#
# ### Voici les problématiques :
# 1. Quelles sont les tendances générales dans la manière dont les couples se rencontrent et forment des relations aux États-Unis, et comment ont-elles changé au fil du temps ?
#
# 2. Dans quelle mesure la religion, la politique et d'autres facteurs influencent-ils la manière dont les couples se rencontrent et se forment, ainsi que la durabilité de leur relation ?
#
# 3. Quelles sont les attitudes envers le mariage et la satisfaction de la relation chez les couples, et comment cela est-il lié à la durée de la relation et à la manière dont les couples se sont rencontrés ?
#
# 4. Comment les rencontres en ligne ont-elles changé la manière dont les couples se rencontrent et forment des relations, et quelles sont les différences entre les couples qui se sont rencontrés en ligne et ceux qui se sont rencontrés dans la vie réelle ?
#
# ### En résumé :
# - De manière générale, comment les couples se rencontrent-ils et nouent-ils des relations aux États-Unis ? Quels sont les changements observés dans ces tendances au fil du temps ?
#
# - Dans quelle mesure les facteurs tels que la religion, la politique et les idéologies similaires ou différentes peuvent-ils influencer la formation et la durabilité des couples, ainsi que leur capacité à maintenir une relation satisfaisante dans le temps ?
#
# - Comment les rencontres en ligne ont-elles modifié la façon dont les couples se rencontrent et entretiennent des relations ? Quelles sont les différences entre les couples qui se sont rencontrés en ligne et ceux qui ont opté pour des rencontres dans la vie réelle ?
# En outre, quels sont les endroits les plus courants pour que les couples se rencontrent ?
# ---
# # Info Data :
# How Couples Meet and Stay Together (HCMST) est une étude sur la façon dont les Américains rencontrent leurs conjoints et partenaires amoureux.
#
# - L'étude est une étude représentative à l'échelle nationale des adultes américains.
# - 4 002 adultes ont répondu à l'enquête, dont 3 009 avaient un conjoint ou un partenaire amoureux principal.
# - L'étude suréchantillonne des adultes homosexuels, lesbiennes et bisexuels auto-identifiés
# - Des enquêtes de suivi ont été mises en place un et deux ans après l'enquête principale, pour étudier les taux de dissolution des couples. La version 3.0 de l'ensemble de données comprend deux enquêtes de suivi, les vagues 2 et 3.
# - Les vagues 4 et 5 sont fournies sous forme de fichiers de données distincts qui peuvent être liés au fichier principal via la variable caseid_new.
# wave 1 = 2009
# wave 2 = 2010
# wave 3 = 2011
# wave 4 = 2013
# wave 5 = 2015
# wave 6 = 2017
# chaque wave correspond à un fichier csv que l'on as.
# ___

# %% [markdown]
# # Transformer les fichier .dta en .csv
# Grace [à cette personne.](https://gist.github.com/clbarnes/3d4cef38806672535a37a7db3c06c0ad)
# Nous avons pus crée ce code qui convertie les fichier .dta en csv

# %%
#!/usr/bin/env python3.7
"""
How Couples Meet and Stay Together

For more information, see [the website](https://data.stanford.edu/hcmst)

Download STATA data (.dta) and put in the same directory as this script.
transforme les fichier dta en csv
"""
from pathlib import Path
import pandas as pd

for fpath in Path().glob("dta/*.dta"):
    print(f"Reading {fpath}")
    df = pd.read_stata(fpath)
    out_fpath = fpath.with_suffix(".csv").name
    print(f"Writing {out_fpath}")
    df.to_csv(fpath.with_suffix(".csv"))

for fpath in Path().glob("dta/*.csv"):
    new_fpath = Path("./csv/Brut") / fpath.name
    print(f"Moving {fpath} to {new_fpath}")
    fpath.rename(new_fpath)
# Out:
# Reading dta\HCMST2017.dta
# Writing HCMST2017.csv
# Moving dta\HCMST2017.csv to csv\HCMST2017.csv

# %% [markdown]
# # Netoyage Des donné
#
# ### explication :
# code qui transfrome tout les "date"HCMS qui sont dans un désorde en un fichier csv avec des tete de page comprénsible et prendre les information utile pour chaque vague.
# ___
# ## wave 3 2011 brut explication
#
# 1. caseid_new: Il s'agit d'un identifiant unique pour chaque participant à l'étude.
#
# 2. weight1:  est un poids d'échantillonnage basé sur les probabilités d'inclusion de chaque répondant dans l'échantillon de l'étude. Il est utilisé pour corriger les biais de sélection potentiels dans les données en donnant un poids plus élevé aux répondants qui ont été sous-échantillonnés.
#
# 3. weight2: est un poids de calibrage qui est utilisé pour équilibrer les caractéristiques de la population totale avec celles de l'échantillon de l'étude. Il est calculé à partir de plusieurs sources d'informations dans les données, notamment les réponses des répondants à des questions sur leur partenaire et leur relation, ainsi que des caractéristiques démographiques clés de la population totale. En utilisant weight2, les chercheurs peuvent produire des estimations plus précises des caractéristiques de la population totale en prenant en compte plusieurs sources d'informations dans les données.
#
# 4. ppage: l'age du partcipant ppage = participant age
#
# 5. ppagecat: Catégorise l'age 28-25 ans etc
#
# 6. ppagecat: c'est pareille que ppagecat mais resumer en 4 catgorie seulement
#
# 7. ppeduc : Cette variable dans la base de données HCMST représente le plus haut niveau d'éducation atteint par le répondant principal. Les réponses sont catégorisées en huit niveaux d'éducation différents, allant de "pas de diplôme" à "doctorat". Cette variable peut être utilisée pour examiner l'influence de l'éducation sur les relations amoureuses et d'autres variables d'intérêt.
#
# 8. ppeducat : Cette variable est une version catégorisée de la variable ppeduc. Elle regroupe les répondants en seulement quatre catégories d'éducation différentes : "pas de diplôme", "diplôme d'études secondaires (ou équivalent)", "certificat universitaire ou diplôme associé" et "baccalauréat ou diplôme universitaire supérieur".
#
# 9. ppethm : Cette variable dans la base de données HCMST représente l'origine ethnique ou raciale auto-déclarée du répondant principal. Les réponses sont catégorisées en six groupes ethniques ou raciaux différents, y compris Blanc, Noir, Latino, Asiatique, Indien d'Amérique/Alaska natif, et autre. Cette variable peut être utilisée pour examiner les différences dans les relations amoureuses et les comportements entre les groupes ethniques ou raciaux.
#
# 10. ppgender : Cette variable dans la base de données HCMST représente le genre auto-déclaré du répondant principal. Les réponses sont catégorisées en deux groupes : "homme" et "femme". Cette variable peut être utilisée pour examiner les différences entre les genres dans les relations amoureuses et d'autres variables d'intérêt.
#
# 11. pphhhead : Cette variable dans la base de données HCMST indique si le répondant principal est le chef de ménage ou non. Les réponses sont catégorisées en deux groupes : "oui" et "non". Cette variable peut être utilisée pour examiner les différences entre les répondants chefs de ménage et non-chefs de ménage dans les relations amoureuses et d'autres variables d'intérêt. (pas compris)
#
# 12. pphouseholdsize : nombre de personnes vivant dans le ménage du répondant
#
# 13. pphouse : type de logement du répondant (propriété, location, etc.)
#
# 14. ppincimp : revenu du ménage du répondant
#
# 15. hhinc : revenu du ménage exprimé en catégories
#
# 16. ppmarit : état matrimonial du répondant (marié, célibataire, divorcé, etc.)
#
# 17. ppmsacat : catégorie métropolitaine de la zone de résidence du répondant (grandes villes, banlieues, zones rurales, etc.)
#
# 18. ppreg4 : région géographique du répondant (nord-est, sud, etc.)
#
# 19. ppreg9 : région géographique du répondant (découpage plus fin que ppreg4)
#
# 20. pprent : statut de propriété du logement du répondant (propriétaire, locataire, etc.)
#
# 21. ppt01 : nombre d'enfants de moins de 1 an vivant dans le ménage du répondant
#
# 22. ppt1317 : nombre d'enfants âgés de 13 à 17 ans vivant dans le ménage du répondant
#
# 23. ppt18ov : nombre de personnes âgées de 18 ans ou plus vivant dans le ménage du répondant
#
# 24. ppt25 : nombre d'enfants âgés de 2 à 5 ans vivant dans le ménage du répondant
#
# 25. ppt612 : nombre d'enfants âgés de 6 à 12 ans vivant dans le ménage du répondant
#
# 26. children_in_hh : variable binaire indiquant si le répondant a des enfants vivant dans son ménage ou non
#
# 27. ppwork : statut d'emploi actuel du répondant (travail à temps plein, travail à temps partiel, sans emploi, etc.)
#
# 28. ppnet : revenu net annuel du répondant (en dollars américains)
#
# 29. ppq14arace : catégorie de race/ethnicité à laquelle le répondant s'identifie (blanc, noir, hispanique, asiatique, etc.)
#
# 30. pphispan : variable binaire indiquant si le répondant s'identifie comme hispanique ou latino
#
# 31. pprace_white, pprace_black, pprace_nativeamerican, pprace_asianindian, pprace_filipino, pprace_japanese, pprace_koreann, pprace_vietnamese, pprace_otherasian, pprace_hawaiian, pprace_guamanian, pprace_samoan, pprace_otherpacislander : variables binaires indiquant si le répondant s'identifie comme appartenant à l'un de ces groupes raciaux/ethniques.
#
# 32. pprace_someotherrace : variable binaire indiquant si le répondant s'identifie comme appartenant à une autre race non mentionnée dans les autres variables de race (par exemple, arabe, multiracial, etc.).
#
# 33. papgib_friend : variable binaire indiquant si le répondant a un ami proche qui est gay, lesbien, bisexuel ou queer (GLBQ).
#
# 34. pppartyid3 : variable indiquant l'appartenance politique auto-déclarée du répondant, avec les catégories "démocrate", "républicain" et "indépendant".
#
# 35. papevangelical : variable binaire indiquant si le répondant s'identifie comme évangélique ou non.
#
# 36. papreligion : variable catégorielle indiquant la religion auto-déclarée du répondant.
#
# 37. pppcmdate_yrmo : variable indiquant le mois et l'année où le répondant a rempli l'enquête pour la première fois. Cette variable est mesurée en termes de mois et d'année, dans le format "AAAA-MM".
#
# 38. pppdate_yrmo : variable indiquant le mois et l'année où le répondant a rempli l'enquête pour la dernière fois. Cette variable est également mesurée en termes de mois et d'année, dans le format "AAAA-MM".
#
# 39. pphhcomp11_memberX_age : Ces variables pphhcomp11_memberX_age indiquent l'âge de chaque membre supplémentaire du ménage vivant sous le même toit que le répondant, où X est un numéro de membre variant de 3 à 15.
#
# 40. pphhcomp11_memberX_gender: Ces variables pphhcomp11_memberX_gender indiquent le genre de chaque membre supplémentaire du ménage vivant sous le même toit que le répondant, où X est un numéro de membre variant de 3 à 15.
#
# 41. pphhcomp11_memberX_relationship : indiquent la relation de chaque membre supplémentaire du ménage vivant sous le même toit que le répondant, où X est un numéro de membre variant de 3 à 15.
#
# 42. irb_consent : le participant qui donne son consentement
#
# 43. weightx : Les variables weight (poids) sont des poids d'échantillonnage utilisés pour ajuster les données afin qu'elles représentent la population cible. (je ne comprend pas comment cela diminue les biais?)
#
# 44. weight_couples_coresident : Le poids d'échantillonnage pour les couples vivant ensemble dans le ménage, ajusté pour représenter la population cible.
#
# 45. HCMST_main_interview_yrmo : L'année et le mois de l'interview principale de HCMST.
#
# 46. duration : Durée de l'interview en minutes et secondes.
#
# 47. qflag : Drapeau de qualité des données qui indique si les données de l'interview doivent être utilisées avec précaution.
#
# 48. glbstatus : Statut de l'enquêteur pour savoir s'il a complété l'entrevue.
#
# 49. papglb_status : Statut de l'entretien pour savoir s'il a été complété et s'il est utilisable.
#
# 50. recsource : la source à partir de laquelle les participants ont été recrutés pour l'étude.
#
# 51. s1 : une variable qui indique si les participants son marier
#
# 52. s1a : une variable qui indique si les participants on deja etait marier (je pense)
#
# 53. s2 : une variable qui indique si les participants son on couple ou non
#
# 54. q3_codes : une variable qui contient les réponses codées des participants à une question sur la fréquence à laquelle ils ont discuté avec leur partenaire de différents sujets (par exemple, l'argent, la sexualité, etc.)(pas sure)
#
# 55. q4 : une variable qui contient le genre (male ou female) du conjoint ou du partenaire actuel de la personne interrogée.
#
# 56. q5 : une variable qui dis si le participant à le meme sex que leur partener.
#
# 57. q6a : une variable qui contient si leur partener et latino ou non.
#
#
# 58. q6b : dis l'ethnie ou lorigine de leur partenaire
#
# 59. q7a : jsp
#
# 60. q7b : specifie quelle branche de christianimse est leur conjoin
#
# 61. q8a : dis si leur conjoint a la meme religion et si ils l'on changer
#
# 62. q8b : précise la religion de leur conjoin
#
# 63. q9 : l'age de leur conjoin je pense
#
# BON je marrete la il y a beaucoup trop de variable juste pour 1 csv je vais dabbord juste recuperer les info qui minterresse et puis voila et directment repondre au problématique.
